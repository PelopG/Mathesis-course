# %% [markdown]
# Multiple regression example

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# In multiple regression we start with a hypothesis that there is a relationship between dependent variable (y) and independent variables
# (x1,x2,x3...,xn)
#
# y=α+β1x1+β2x2+⋯+βnxn+ϵ
#
# We want to find out α & βi
#
# Lets go back to the Galton example

# %%
galton_families = sm.datasets.get_rdataset("GaltonFamilies", package="HistData")

galton_families.data
# Out:
#     family  father  mother  midparentHeight  children  childNum  gender  \
# 0      001    78.5    67.0            75.43         4         1    male
# 1      001    78.5    67.0            75.43         4         2  female
# 2      001    78.5    67.0            75.43         4         3  female
# 3      001    78.5    67.0            75.43         4         4  female
# 4      002    75.5    66.5            73.66         4         1    male
# ..     ...     ...     ...              ...       ...       ...     ...
# 929    203    62.0    66.0            66.64         3         1    male
# 930    203    62.0    66.0            66.64         3         2  female
# 931    203    62.0    66.0            66.64         3         3  female
# 932    204    62.5    63.0            65.27         2         1    male
# 933    204    62.5    63.0            65.27         2         2  female
#
#      childHeight
# 0           73.2
# 1           69.2
# 2           69.0
# 3           69.0
# ...

# %% [markdown]
# Lets now take the relatioship between the son and the height of both parents

# %%
parents_sons = galton_families.data[galton_families.data['gender'] == 'male']
parents_sons
# Out:
#     family  father  mother  midparentHeight  children  childNum gender  \
# 0      001    78.5    67.0            75.43         4         1   male
# 4      002    75.5    66.5            73.66         4         1   male
# 5      002    75.5    66.5            73.66         4         2   male
# 8      003    75.0    64.0            72.06         2         1   male
# 10     004    75.0    64.0            72.06         5         1   male
# ..     ...     ...     ...              ...       ...       ...    ...
# 918    199    64.0    64.0            66.56         7         2   male
# 924    200    64.0    63.0            66.02         1         1   male
# 925    201    64.0    60.0            64.40         2         1   male
# 929    203    62.0    66.0            66.64         3         1   male
# 932    204    62.5    63.0            65.27         2         1   male
#
#      childHeight
# 0           73.2
# 4           73.5
# 5           72.5
# 8           71.0
# 10          70.5
# ...

# %% [markdown]
# In order to create a model with more than one independent variable we need to use the + operator

# %%
parents_sons_mod = smf.ols("childHeight ~ father +  mother", data=parents_sons)
parents_sons_res = parents_sons_mod.fit()
parents_sons_res.params
# Out:
# Intercept    19.312813
# father        0.417556
# mother        0.328773
# dtype: float64

# %% [markdown]
# This means that the variable childHeight (y) and father(x1) and mother(x2) can be described by mathematical equation:
#
# y=19,312813+0,417556x1+0,328773x2

# %% [markdown]
# In multiple regression we cannot design diagrams like in linear regression because we now have 3 diamensions instead of 2.

# %%
# Summary
parents_sons_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            childHeight   R-squared:                       0.238
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     74.62
# Date:                Tue, 29 Mar 2022   Prob (F-statistic):           6.25e-29
# Time:                        20:53:04   Log-Likelihood:                -1080.7
# No. Observations:                 481   AIC:                             2167.
# Df Residuals:                     478   BIC:                             2180.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     19.3128      4.095      4.716      0.000      11.266      27.359
# ...

# %%
# Lets compare the data with the previous model - father height and child height

fathers_sons_mod = smf.ols("childHeight ~ father", data=parents_sons)
fathers_sons_res = fathers_sons_mod.fit()
print('Fathers and sons')
print(fathers_sons_res.params)
print('R-squared:', fathers_sons_res.rsquared)
print('Parents and sons')
print(parents_sons_res.params)
print('R-squared:', parents_sons_res.rsquared)
# Out:
# Fathers and sons
# Intercept    38.362581
# father        0.446523
# dtype: float64
# R-squared: 0.1539648084533538
# Parents and sons
# Intercept    19.312813
# father        0.417556
# mother        0.328773
# dtype: float64
# R-squared: 0.2379383596930773

# %% [markdown]
# We can se that R^2 increases significantly - good choice implementing the height of mother as well
#
# Also father variable has changed from before after implementing mother height also.
# This is because that the mother height affect the child height and also that tall women tend to marry tall guys.

# %% [markdown]
# Another example is to regarding the house prices in California
#
# Note:
#
# Since the file downloaded was a tgz we need to use the following:

# %%
import tarfile
with tarfile.open("cal_housing.tgz", "r") as tar:
    file_paths = tar.getnames()
    col_list = pd.read_csv(tar.extractfile(file_paths[1]), header=None).values
    flat_col_list = [item.split(':')[0] for sublist in col_list for item in sublist]
    cal_housing = pd.read_csv(tar.extractfile(file_paths[0]), header=None,
                              names=flat_col_list, index_col=False)
cal_housing
# Out:
#        longitude  latitude  housingMedianAge  totalRooms  totalBedrooms  \
# 0        -122.23     37.88              41.0       880.0          129.0
# 1        -122.22     37.86              21.0      7099.0         1106.0
# 2        -122.24     37.85              52.0      1467.0          190.0
# 3        -122.25     37.85              52.0      1274.0          235.0
# 4        -122.25     37.85              52.0      1627.0          280.0
# ...          ...       ...               ...         ...            ...
# 20635    -121.09     39.48              25.0      1665.0          374.0
# 20636    -121.21     39.49              18.0       697.0          150.0
# 20637    -121.22     39.43              17.0      2254.0          485.0
# 20638    -121.32     39.43              18.0      1860.0          409.0
# 20639    -121.24     39.37              16.0      2785.0          616.0
#
#        population  households  medianIncome  medianHouseValue
# ...

# %% [markdown]
# Note:
#
# Its always a good idea to take a visual representation of the data by creating a histrogram.

# %%
# Creating histogram using pandas
cal_housing.hist(figsize=(12, 10), bins=30, edgecolor="black")
plt.subplots_adjust(hspace=0.7, wspace=0.4)

# %% [markdown]
# We can see from the longitude and latitude of the houses that the houses in California are scatter around into 2 values .

# %%
independent_variables = ' + '.join(cal_housing.columns[:-1])
print(independent_variables)
cal_housing_mod = smf.ols("medianHouseValue ~ " + independent_variables, data=cal_housing)
# Out:
# longitude + latitude + housingMedianAge + totalRooms + totalBedrooms + population + households + medianIncome

# %%
#Summary
cal_housing_res = cal_housing_mod.fit()
cal_housing_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       medianHouseValue   R-squared:                       0.637
# Model:                            OLS   Adj. R-squared:                  0.637
# Method:                 Least Squares   F-statistic:                     4528.
# Date:                Tue, 29 Mar 2022   Prob (F-statistic):               0.00
# Time:                        21:11:34   Log-Likelihood:            -2.5941e+05
# No. Observations:               20640   AIC:                         5.188e+05
# Df Residuals:                   20631   BIC:                         5.189e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# We can see a high R^2 value
# and also that the price is affected by the location of the houses (longitude) & (latitude)
#
# Hence should we also examine the interaction of longitude and lattitude?
# Specif values of both variables can affect the price?
#
# When we have 2 independent variables (xi) & (xj) we can insert the interaction in the model using the multiplication pf (xi) & (xj)
#
# We write that by longitude:latitude
#
# longitude*latitude = longitude + latitude + longitude:latitude

# %%
independent_variables = "housingMedianAge + totalRooms + totalBedrooms + population"
independent_variables += " + households + medianIncome"
independent_variables += " + longitude*latitude"
cal_housing_mod = smf.ols("medianHouseValue ~ " + independent_variables, data=cal_housing)
print(independent_variables)
cal_housing_res = cal_housing_mod.fit()
cal_housing_res.summary()
# Out:
# housingMedianAge + totalRooms + totalBedrooms + population + households + medianIncome + longitude*latitude
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       medianHouseValue   R-squared:                       0.637
# Model:                            OLS   Adj. R-squared:                  0.637
# Method:                 Least Squares   F-statistic:                     4029.
# Date:                Tue, 29 Mar 2022   Prob (F-statistic):               0.00
# Time:                        21:16:11   Log-Likelihood:            -2.5940e+05
# No. Observations:               20640   AIC:                         5.188e+05
# Df Residuals:                   20630   BIC:                         5.189e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# We can see that longitude:latitude is affected by the price of houses
#
# The value latitude corresponds to the pirce of houses
#
# When the latitude increases by 0.1 and the longitude stays at 0

# %%
independent_variables = (
    'longitude*latitude',
    'housingMedianAge',
    'totalBedrooms',
    'population',
    'households',
    'medianIncome')
cal_housing_mod = smf.ols("medianHouseValue ~ " + '+'.join(independent_variables), data=cal_housing)
cal_housing_res = cal_housing_mod.fit()
cal_housing_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       medianHouseValue   R-squared:                       0.636
# Model:                            OLS   Adj. R-squared:                  0.635
# Method:                 Least Squares   F-statistic:                     4497.
# Date:                Tue, 29 Mar 2022   Prob (F-statistic):               0.00
# Time:                        21:20:34   Log-Likelihood:            -2.5945e+05
# No. Observations:               20640   AIC:                         5.189e+05
# Df Residuals:                   20631   BIC:                         5.190e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
# Lets create a diagram based on location
plt.figure(figsize=(10, 8))
sns.set_theme(font_scale=1.5)
sns.scatterplot(data=cal_housing, 
                x="longitude", y="latitude", size="medianHouseValue", hue="medianHouseValue",
                palette="viridis", alpha=0.5)
plt.legend(title="medianHouseValue", bbox_to_anchor=(1.05, 0.95), loc="upper left")
_ = plt.title("Median house value depending on location")

# %% [markdown]
# High prices house tend to be near the ocean whereas price decreases as we move furhter in.

# %%
# Lets go back to the diamond example
from plotnine.data import diamonds
diamonds_mod = smf.ols("np.log2(price) ~ np.log2(carat)", 
                       data=diamonds.query('carat <= 2.5'))
diamonds_res = diamonds_mod.fit()
diamonds_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         np.log2(price)   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                 7.542e+05
# Date:                Tue, 29 Mar 2022   Prob (F-statistic):               0.00
# Time:                        21:22:27   Log-Likelihood:                -23824.
# No. Observations:               53814   AIC:                         4.765e+04
# Df Residuals:                   53812   BIC:                         4.767e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# Lets now add the independent variables clarity color and cut
#
# These variables are already in categories (categorical variables) and in pandas we need to correlate these variables with numbers

# %%
diamonds_mod = smf.ols("np.log2(price) ~ np.log2(carat)"
                       + "+ clarity.cat.codes + color.cat.codes + cut.cat.codes", # here we take the number 
                       data=diamonds.query('carat <= 2.5'))
diamonds_res = diamonds_mod.fit()
diamonds_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         np.log2(price)   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                 6.474e+05
# Date:                Tue, 29 Mar 2022   Prob (F-statistic):               0.00
# Time:                        21:24:43   Log-Likelihood:                 8068.7
# No. Observations:               53814   AIC:                        -1.613e+04
# Df Residuals:                   53809   BIC:                        -1.608e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# R^2 increases from before
#
# This new model npow fits better the data
#
# We can see that the price of diamonds is affected by:
#
# - clarity increase price
#
# - color reduces price
#
# - cut increases price
#
# - and carat increases price
