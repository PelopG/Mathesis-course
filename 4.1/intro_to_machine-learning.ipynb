# %% [markdown]
# This is a small introduction to machine learning.
#
# According to Wikipedia - machine learning is the study if computer algrorithms that can improve automatically through experience and by the use of data
#
# Machine learning approaches are traditionally divided into three broad categories, depending on the nature of the "signal" or "feedback" available to the learning system:
#
# 1) Supervised: The computer is presented with example inputs and their desired outputs, given by a "teacher", and the goal is to learn a general rule that maps inputs to outputs.
#
# Typical uses: classification and regression
# Classification is taking the data and categorizing them
#
# Example taking medical records and clasiffiing them as healthly or not healthy
#
# Regression the thing we would like to predict is not a category but rather a numerical value
#
# Example: We have as set of data for houses and we want to predict the price houses
#
# * Note: This is different from the regression we have seen in the other parts. (statistical regression)
#
# 2) Unsupervised: No labels are given to the learning algorithm, leaving it on its own to find structure in its input. Unsupervised learning can be a goal in itself (discovering hidden patterns in data) or a means towards an end (feature learning).
#
# Typical uses: clustering and dimensionality reduction
# Clustering: The task of grouping a set of objects in such a way that objects in the same group (called a cluster) are more similar (in some sense) to each other than to those in other groups (clusters).
#
# Dimensionality reduction: is the transformation of data from a high-dimensional space into a low-dimensional space so that the low-dimensional representation retains some meaningful properties of the original data
#
#
# 3) Reinforcement learning: A computer program interacts with a dynamic environment in which it must perform a certain goal (such as driving a vehicle or playing a game against an opponent). As it navigates its problem space, the program is provided feedback that's analogous to rewards, which it tries to maximize

# %% [markdown]
# In this topic we are going to use the two_class folder which has different png
# References will be made from that folder.

# %% [markdown]
# <img src="two_classes_1/.two_classes.png">
#
# From the graph we can see 2 different classes (0&1)
#
# Lets say that we now have another point of the graph. - indicated by a black cross.
#
# <img src="two_classes_1/two_classes_classify_x.png" />
#
# Now to which class does this point belong to? red or blue?
#
# What we want to do is to teach the computer how to thing based on the information found on the graph - most importanly being able to place a new point to the correct class.
#
# A solution to the problem is that we can seperate the graph by a line:
#
# <img src="two_classes_1/two_classes_three_classifiers.png" />
#
# 3 possible line can be found on the above photo
#
# We can say now that whatever is above the line is contained to 1 category and whatever is below the line is contained to another category ( red or blue depending on position)
#
#
# Now the question is, which line do we select?
#
# Solution:
#
# We set a (margin) which indicated the minimum distance of the line from the points
#
# <img src="two_classes_1/two_classes_three_classifiers_margins.png" />
#
# Drawing now the 3 lines with there margins.
#
# Which line do we select?
#
# We select the line with the maximal margin classifier - since it seperates our data in the best possible way
#
# In our case the first line best seperates out data
#
# <img src="two_classes_1/two_classes_classifier_margin.png" />
#
# Therefore since now we have identified the line we can find the mathematical equation of the line:
#
# 𝑦=0,17𝑥+2,32
#
# The result form the learning is the equation of the line , specificly the parameters m (gradient) and c ( y-intercept)
#
#
# Note:
#
# A best fit line is affected by the point near it. The rest of the point do not really matter
#
# The points that make up the line are called (support vectors). Which are the point which are touching the margins
#
# <img src="two_classes_1/two_classes_classifier_support_vectors.png" />
#
# In general we do not usually have to do all this process to be able to identify the best fit line . Since there can be infitine amount of lines.
#
# This is where machine learning comes in and excutes the this algorithm for us.
# Learns the parameters that seperate the lines.
#
#
# Most times our data do not contain only 2 dimensions but rather more and also more data
#
# Generally in order to seperate the dimensions we have to identify the general plane called (hypeplane) - this can be done by an algorithm.
#
#
# Lets now add to our graph a point of class 0 at position (0,2)
#
# <img src="two_classes_1/two_classes_classifier_extra_point.png" />
#
# We can see that this is a red point - but is found under the line rather than above it.
#
# Hence now the line does not seperate the graph into 2 classes.
#
# 𝑦=0,61𝑥+1,34 --> New equation of line
#
# Running the algorithm we have discussed previously;
# We now get a new line
#
# <img src="two_classes_1/two_classes_classifier_extra_point_updated.png" />
#
#
# If we thing more deeply about it , a single point added to the graph has created a completely new line
#
# We may need for example a line which is not affected so much by added points.
#
# Hence we now need a new algorithm that will now be affected too much by newly added points  - be more lenient.
#
# Having done this we can see that the new line is much better that the previous one . Again the line is wrong but it much better than before
#
# <img src="two_classes_1/two_classes_sv_classifier.png" />
#
# This new algorithm which controls how lenient the line will be affected from the points ( Support Vector Classifier )
#
# Note:
#
# In Machine learning the parameters that affect the workings of an algorithm are called (hyperparameters)
#
#
# Lets now see another example with different data.
#
# <img src="two_classes_1/two_classes_nlseparable.png" />
#
# We can see from the above graph that the data are not linearly seperable.
#
#
# Hence we need to find a way to solve this problem.
#
# If our data are not linearly seperable then what we do is that we increase the number of dimensions until we there are linearly seperable.
#
# We can add a 3rd dimension using:
#
# 𝑧=𝑒^−(𝑥2+𝑦2) --> this mathematical equation
#
# Therefore:
#
# <img src="two_classes_1/two_classes_nlseparable_3d.png" />
#
# Running the required algorithm for linear seperable data and we then project it to 2D
#
# <img src="two_classes_1/two_classes_nlseparable_2d.png" />
#
# In Machine learning we call this as (Support Vector Machine)
#
# Researches have writtern different functions like the once we have discussed which result to manipulation of non linearly seperable data.
#
# These algorithms are called (kernel functions)
